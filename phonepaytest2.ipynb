# %%
import psycopg2
import pandas as pd
import plotly.express as px

# %%
# Dataframe Creation

#sql connection
mydb = psycopg2.connect(host = "localhost",
                        user = "postgres",
                        port = 5432,
                        database = "Phonepay_data",
                        password = "your_password")
cursor = mydb.cursor()

#aggre_user_df

cursor.execute("SELECT * FROM aggregated_user")
mydb.commit()
table1 = cursor.fetchall()

Aggre_user = pd.DataFrame(table1, columns=("States", "Years", "Quarter", "Brands", "Transaction_count", "Percentage"))


#aggre_trans_df

cursor.execute("SELECT * FROM aggregated_transaction")
mydb.commit()
table2 = cursor.fetchall()

Aggre_trans = pd.DataFrame(table2, columns=("States", "Years", "Quarter", "Transaction_type", "Transaction_count", "Transaction_amount"))


#aggre_insura_df

cursor.execute("SELECT * FROM aggregated_insurance")
mydb.commit()
table3 = cursor.fetchall()

Aggre_insura = pd.DataFrame(table3, columns=("States", "Years", "Quarter", "Transaction_type", "Transaction_count", "Transaction_amount"))


#Map_usre_df

cursor.execute("SELECT * FROM map_user")
mydb.commit()
table4 = cursor.fetchall()

map_user = pd.DataFrame(table4, columns=("States", "Years", "Quarter", "District", "RegisteredUsers", "AppOpens"))


#Map_trans_df

cursor.execute("SELECT * FROM map_transaction")
mydb.commit()
table5 = cursor.fetchall()

map_trans = pd.DataFrame(table5, columns=("States", "Years", "Quarter", "District", "Transaction_count", "Transaction_amount"))


#Map_insura_df

cursor.execute("SELECT * FROM map_insurance")
mydb.commit()
table6 = cursor.fetchall()

map_insure = pd.DataFrame(table6, columns=("States", "Years", "Quarter", "District", "Transaction_count", "Transaction_amount"))


#Top_use_df

cursor.execute("SELECT * FROM top_user")
mydb.commit()
table7 = cursor.fetchall()

top_user = pd.DataFrame(table7, columns=("States", "Years", "Quarter", "Pincodes", "RegisteredUsers"))


#Top_trans_df

cursor.execute("SELECT * FROM top_transaction")
mydb.commit()
table8 = cursor.fetchall()

top_trans = pd.DataFrame(table8, columns=("States", "Years", "Quarter", "Pincodes", "Transaction_count", "Transaction_amount"))


#Top_insura_df

cursor.execute("SELECT * FROM top_insurance")
mydb.commit()
table9 = cursor.fetchall()

top_insura = pd.DataFrame(table9, columns=("States", "Years", "Quarter", "Pincodes", "Transaction_count", "Transaction_amount"))
